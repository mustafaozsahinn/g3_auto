# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %matplotlib inline
# %matplotlib notebook

plt.rcParams["figure.figsize"] = (10,6)
# plt.rcParams['figure.dpi'] = 100

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
import pandas as pd
import json

# JSON dosyasını yükleyin
with open('as24_cars.json', 'r') as f:
    data = json.load(f)

# DataFrame'e dönüştürün
df0 = pd.json_normalize(data)

# DataFrame'i yazdırın
print(df0)
# Out:
#                    make_model  \
# 0         Mercedes-Benz A 160
# 1       Mercedes-Benz EQE 350
# 2      Mercedes-Benz A 45 AMG
# 3      Mercedes-Benz A 35 AMG
# 4      Mercedes-Benz A 45 AMG
# ...                       ...
# 29475               Volvo S40
# 29476               Volvo C30
# 29477               Volvo S90
# 29478               Volvo S80
# 29479                     NaN
#
#                                        short_description               make  \
# 0                                                    CDi  \nMercedes-Benz\n
# 1                                                   350+  \nMercedes-Benz\n
# 2                                       S 4Matic+ 8G-DCT  \nMercedes-Benz\n
# 3                                         4Matic+ 7G-DCT  \nMercedes-Benz\n
# 4                               200CDI BE Line 4M 7G-DCT  \nMercedes-Benz\n
# ...                                                  ...                ...
# ...

# %%
df = df0.copy()
df1=df0.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29480 entries, 0 to 29479
# Data columns (total 58 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   make_model                28630 non-null  object
#  1   short_description         28630 non-null  object
#  2   make                      28630 non-null  object
#  3   model                     28630 non-null  object
#  4   location                  28630 non-null  object
#  5   price                     28630 non-null  object
#  6   Body type                 28630 non-null  object
#  7   Type                      28630 non-null  object
#  8   Doors                     28271 non-null  object
#  9   Country version           16889 non-null  object
#  10  Offer number              23100 non-null  object
#  11  Warranty                  15784 non-null  object
#  12  Mileage                   28629 non-null  object
# ...

# %%
df.head(5)

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#                make_model         short_description               make  \
# 0     Mercedes-Benz A 160                       CDi  \nMercedes-Benz\n
# 1   Mercedes-Benz EQE 350                      350+  \nMercedes-Benz\n
# 2  Mercedes-Benz A 45 AMG          S 4Matic+ 8G-DCT  \nMercedes-Benz\n
# 3  Mercedes-Benz A 35 AMG            4Matic+ 7G-DCT  \nMercedes-Benz\n
# 4  Mercedes-Benz A 45 AMG  200CDI BE Line 4M 7G-DCT  \nMercedes-Benz\n
#
#                 model                                           location  \
# 0     [\n, A 160 ,\n]  P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...
# 1   [\n, EQE 350 ,\n]       APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES
# 2  [\n, A 45 AMG ,\n]  PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...
# 3  [\n, A 35 AMG ,\n]  Carrer de Provença, 31 Local,  8029 BARCELONA, ES
# 4  [\n, A 45 AMG ,\n]             CARRIL ARAGONES 4,  30007 CASILLAS, ES
#
#         price          body_type                      type        doors  \
# ...

# %%
df.info()

# %%
df["make_model"].unique()
# Out:
# array(['Mercedes-Benz A 160', 'Mercedes-Benz EQE 350',
#        'Mercedes-Benz A 45 AMG', 'Mercedes-Benz A 35 AMG',
#        'Mercedes-Benz C 160', 'Mercedes-Benz CLA 180',
#        'Mercedes-Benz A 220', 'Mercedes-Benz A 200',
#        'Mercedes-Benz A 250', 'Mercedes-Benz A 180',
#        'Mercedes-Benz GLC 220', 'Mercedes-Benz E 220',
#        'Mercedes-Benz B 200', 'Mercedes-Benz A 150',
#        'Mercedes-Benz V 220', 'Mercedes-Benz AMG GT',
#        'Mercedes-Benz E 300', 'Mercedes-Benz EQS', 'Mercedes-Benz A 140',
#        'Mercedes-Benz ', 'Mercedes-Benz CL', 'Mercedes-Benz B 180',
#        'Mercedes-Benz GLB 200', 'Mercedes-Benz E 350',
#        'Mercedes-Benz CLA 200', 'Mercedes-Benz 280',
#        'Mercedes-Benz GLA 180', 'Mercedes-Benz Viano',
#        'Mercedes-Benz E 53 AMG', 'Mercedes-Benz SLK 200',
#        'Mercedes-Benz GLE 350', 'Mercedes-Benz 220',
#        'Mercedes-Benz SL 500', 'Mercedes-Benz E 400',
#        'Mercedes-Benz SLC 43 AMG', 'Mercedes-Benz SL 350',
# ...

# %%
# make_model sütununu make ve model sütunlarına ayırma
df[['make', 'model']] = df['make_model'].str.split(' ', 1, expand=True)

# %%
# make_model sütununu kaldırma
df.drop('make_model', axis=1, inplace=True)

# %%
df.head(1)
# Out:
#   short_description           make  model  \
# 0               CDi  Mercedes-Benz  A 160
#
#                                             location       price  \
# 0  P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...  € 16,950.-
#
#            body_type            type        doors  country_version  \
# 0  [\n, Compact, \n]  [\n, Used, \n]  [\n, 5, \n]  [\n, Spain, \n]
#
#         offer_number             warranty     mileage first_registration  \
# 0  [\n, 7468157, \n]  [\n, 24 months, \n]  120,200 km            06/2016
#
#         gearbox fuel_type colour     paint  \
# 0  [\nManual\n]    Diesel  Black  Metallic
#
#                                                 desc  seller seats power  \
# 0  [ , Precio al contado: 16950 euros,  ,  , Vehí...  Dealer   NaN   NaN
#
#   engine_size gears co₂-emissions manufacturer_colour drivetrain cylinders  \
# 0         NaN   NaN           NaN                 NaN        NaN       NaN
#
# ...

# %%
df.columns
# Out:
# Index(['short_description', 'make', 'model', 'location', 'price', 'body_type',
#        'type', 'doors', 'country_version', 'offer_number', 'warranty',
#        'mileage', 'first_registration', 'gearbox', 'fuel_type', 'colour',
#        'paint', 'desc', 'seller', 'seats', 'power', 'engine_size', 'gears',
#        'co₂-emissions', 'manufacturer_colour', 'drivetrain', 'cylinders',
#        'fuel_consumption', '\ncomfort_&_convenience\n',
#        '\nentertainment_&_media\n', '\nsafety_&_security\n', '\nextras\n',
#        'empty_weight', 'model_code', 'general_inspection', 'last_service',
#        'full_service_history', 'non-smoker_vehicle', 'emission_class',
#        'emissions_sticker', 'upholstery_colour', 'upholstery',
#        'production_date', 'previous_owner', 'other_fuel_types',
#        'power_consumption', 'energy_efficiency_class', 'co₂-efficiency',
#        'fuel_consumption_(wltp)', 'co₂-emissions_(wltp)', 'available_from',
# ...

# %%
df['comfort_&_convenience']=df['\ncomfort_&_convenience\n']
df['entertainment_&_media']=df['\nentertainment_&_media\n']
df['safety_&_security']=df['\nsafety_&_security\n']
df['extras']=df['\nextras\n']

# %%
df.columns

# %%
df_cloumn = ['\ncomfort_&_convenience\n','\nentertainment_&_media\n', '\nsafety_&_security\n', '\nextras\n']
df.drop(df_cloumn, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['short_description', 'make', 'model', 'location', 'price', 'body_type',
#        'type', 'doors', 'country_version', 'offer_number', 'warranty',
#        'mileage', 'first_registration', 'gearbox', 'fuel_type', 'colour',
#        'paint', 'desc', 'seller', 'seats', 'power', 'engine_size', 'gears',
#        'co₂-emissions', 'manufacturer_colour', 'drivetrain', 'cylinders',
#        'fuel_consumption', 'empty_weight', 'model_code', 'general_inspection',
#        'last_service', 'full_service_history', 'non-smoker_vehicle',
#        'emission_class', 'emissions_sticker', 'upholstery_colour',
#        'upholstery', 'production_date', 'previous_owner', 'other_fuel_types',
#        'power_consumption', 'energy_efficiency_class', 'co₂-efficiency',
#        'fuel_consumption_(wltp)', 'co₂-emissions_(wltp)', 'available_from',
#        'taxi_or_rental_car', 'availability', 'last_timing_belt_change',
#        'electric_range_(wltp)', 'power_consumption_(wltp)',
# ...

# %%
df.shape
# Out:
# (29480, 57)

# %%
df.isnull().sum()
#önce DataFrame'in her bir elemanının boş olup olmadığını kontrol eder ve her bir boş değer için True değeri döndürür.
#Daha sonra, her sütundaki tüm True değerlerinin sayısını toplayarak, her sütundaki toplam boş değer sayısını veren bir 
#Seri oluşturur.
# Out:
# short_description             850
# make                          850
# model                         850
# location                      850
# price                         850
# body_type                     850
# type                          850
# doors                        1209
# country_version             12591
# offer_number                 6380
# warranty                    13696
# mileage                       851
# first_registration            852
# gearbox                      1098
# fuel_type                    2637
# colour                       2574
# paint                       14985
# desc                         1433
# seller                        850
# seats                        3975
# power                        1422
# engine_size                  2253
# gears                       10526
# co₂-emissions               10886
# manufacturer_colour          7693
# drivetrain                  12587
# cylinders                   10628
# ...

# %%
(df.isnull().sum()/len(df)*100)
#DataFrame'deki her bir sütundaki boş değerlerin yüzdesini hesaplar.
#Bu ifadenin sonucu, her bir sütunda bulunan boş değerlerin yüzdesini içeren bir Seri'dir.
# Out:
# short_description           2.883
# make                        2.883
# model                       2.883
# location                    2.883
# price                       2.883
# body_type                   2.883
# type                        2.883
# doors                       4.101
# country_version            42.710
# offer_number               21.642
# warranty                   46.459
# mileage                     2.887
# first_registration          2.890
# gearbox                     3.725
# fuel_type                   8.945
# colour                      8.731
# paint                      50.831
# desc                        4.861
# seller                      2.883
# seats                      13.484
# power                       4.824
# engine_size                 7.642
# gears                      35.706
# co₂-emissions              36.927
# manufacturer_colour        26.096
# drivetrain                 42.697
# cylinders                  36.052
# ...

# %%
#burada aslında çok null olan verileri düşebiliriz. ama o oranı neye göre belirlemek lazım bilmiyorum.

# %% [markdown]
# # short_description

# %%
#short_description
df.short_description.value_counts()
# Out:
#                                                       213
# D2 Momentum 120                                        88
# D2 Kinetic 120                                         87
# Cabrio 1.4T S&S Excellence                             85
# Extreme+ 7-Sitzer TCe 110                              57
#                                                      ...
# PureTech  EAT8 Allure Pack...DISP. PER NOLEGGIO         1
# BlueHDi 130 S&S EAT8 Business                           1
# 2.0 BlueHDi 180ch S\u0026S GT Line EAT8                 1
# 1.2 PureTech Première AUT. NAVI PANO                    1
# 2.9 Executive G. NETTE AUTO! LEER! NAVI! CRUISE! L      1
# Name: short_description, Length: 20947, dtype: int64

# %%
df

# %%
df['short_description']
# Out:
# 0                                                      CDi
# 1                                                     350+
# 2                                         S 4Matic+ 8G-DCT
# 3                                           4Matic+ 7G-DCT
# 4                                 200CDI BE Line 4M 7G-DCT
#                                ...
# 29475          2.4i Momentum/ Airco/ NAP/ APK/ Elek. Ramen
# 29476                      1.6 D DRIVe Start/Stop R-design
# 29477    T5 AUT(8) MOMENTUM BUSINESS SCHUIFDAK 360GR CA...
# 29478    2.9 Executive G. NETTE AUTO! LEER! NAVI! CRUIS...
# 29479                                                  NaN
# Name: short_description, Length: 29480, dtype: object

# %%
df.loc[df['short_description'] ==''].head(213)
# Out:
#       short_description           make  model  \
# 22                       Mercedes-Benz  A 180
# 23                       Mercedes-Benz  A 200
# 31                       Mercedes-Benz  A 180
# 35                       Mercedes-Benz  A 180
# 55                       Mercedes-Benz  A 200
# ...                 ...            ...    ...
# 27696                            Volvo   XC90
# 28092                            Volvo   XC90
# 29239                            Volvo    S90
# 29258                            Volvo    V40
# 29279                            Volvo    S90
#
#                                             location       price  \
# 22          AVDA. ANDALUCIA, S/N,  18015 GRANADA, ES  € 32,900.-
# 23                  Oeverstraat 3,  9160 Lokeren, BE  € 32,950.-
# 31       Kortrijksesteenweg 395,  8530 Harelbeke, BE  € 32,950.-
# 35      CTRA DE MADRID KM 315,7,  50012 ZARAGOZA, ES  € 25,900.-
# 55                       Bruglaan 55,  3960 Bree, BE  € 27,999.-
# ...

# %%
df[df['short_description'].isnull()==True]
# Out:
#       short_description make model location price body_type type doors  \
# 1785                NaN  NaN   NaN      NaN   NaN       NaN  NaN   NaN
# 1814                NaN  NaN   NaN      NaN   NaN       NaN  NaN   NaN
# 2700                NaN  NaN   NaN      NaN   NaN       NaN  NaN   NaN
# 3008                NaN  NaN   NaN      NaN   NaN       NaN  NaN   NaN
# 3114                NaN  NaN   NaN      NaN   NaN       NaN  NaN   NaN
# ...                 ...  ...   ...      ...   ...       ...  ...   ...
# 29419               NaN  NaN   NaN      NaN   NaN       NaN  NaN   NaN
# 29445               NaN  NaN   NaN      NaN   NaN       NaN  NaN   NaN
# 29451               NaN  NaN   NaN      NaN   NaN       NaN  NaN   NaN
# 29473               NaN  NaN   NaN      NaN   NaN       NaN  NaN   NaN
# 29479               NaN  NaN   NaN      NaN   NaN       NaN  NaN   NaN
#
#       country_version offer_number warranty mileage first_registration  \
# ...

# %%
df.dropna(subset=['short_description'], inplace=True)

# %%
df.shape
# Out:
# (28630, 57)

# %% [markdown]
# # make

# %%
df.make.value_counts()
# Out:
# Volvo            3659
# Mercedes-Benz    2398
# Opel             2385
# Peugeot          2360
# Renault          2351
# Fiat             2338
# Ford             2324
# Nissan           2064
# Toyota           2038
# Hyundai          1867
# SEAT             1743
# Skoda            1566
# Dacia            1537
# Name: make, dtype: int64

# %%
df['make']
# Out:
# 0        Mercedes-Benz
# 1        Mercedes-Benz
# 2        Mercedes-Benz
# 3        Mercedes-Benz
# 4        Mercedes-Benz
#              ...
# 29474            Volvo
# 29475            Volvo
# 29476            Volvo
# 29477            Volvo
# 29478            Volvo
# Name: make, Length: 28630, dtype: object

# %%
df[df['make'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [short_description, make, model, location, price, body_type, type, doors, country_version, offer_number, warranty, mileage, first_registration, gearbox, fuel_type, colour, paint, desc, seller, seats, power, engine_size, gears, co₂-emissions, manufacturer_colour, drivetrain, cylinders, fuel_consumption, empty_weight, model_code, general_inspection, last_service, full_service_history, non-smoker_vehicle, emission_class, emissions_sticker, upholstery_colour, upholstery, production_date, previous_owner, other_fuel_types, power_consumption, energy_efficiency_class, co₂-efficiency, fuel_consumption_(wltp), co₂-emissions_(wltp), available_from, taxi_or_rental_car, availability, last_timing_belt_change, electric_range_(wltp), power_consumption_(wltp), battery_ownership, comfort_&_convenience, entertainment_&_media, safety_&_security, extras]
# Index: []

# %%
df.loc[df['make'] =='']
# Out:
# Empty DataFrame
# Columns: [short_description, make, model, location, price, body_type, type, doors, country_version, offer_number, warranty, mileage, first_registration, gearbox, fuel_type, colour, paint, desc, seller, seats, power, engine_size, gears, co₂-emissions, manufacturer_colour, drivetrain, cylinders, fuel_consumption, empty_weight, model_code, general_inspection, last_service, full_service_history, non-smoker_vehicle, emission_class, emissions_sticker, upholstery_colour, upholstery, production_date, previous_owner, other_fuel_types, power_consumption, energy_efficiency_class, co₂-efficiency, fuel_consumption_(wltp), co₂-emissions_(wltp), available_from, taxi_or_rental_car, availability, last_timing_belt_change, electric_range_(wltp), power_consumption_(wltp), battery_ownership, comfort_&_convenience, entertainment_&_media, safety_&_security, extras]
# Index: []

# %% [markdown]
# # model

# %%
df.model.value_counts()
# Out:
# Megane        863
# Leon          787
# V40           740
# Sandero       730
# i30           706
#              ...
# GLA 35 AMG      1
# G 55 AMG        1
# Ariya           1
# 105             1
# 244             1
# Name: model, Length: 594, dtype: int64

# %%
df['model']
# Out:
# 0           A 160
# 1         EQE 350
# 2        A 45 AMG
# 3        A 35 AMG
# 4        A 45 AMG
#            ...
# 29474         S90
# 29475         S40
# 29476         C30
# 29477         S90
# 29478         S80
# Name: model, Length: 28630, dtype: object

# %%
df[df['model'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [short_description, make, model, location, price, body_type, type, doors, country_version, offer_number, warranty, mileage, first_registration, gearbox, fuel_type, colour, paint, desc, seller, seats, power, engine_size, gears, co₂-emissions, manufacturer_colour, drivetrain, cylinders, fuel_consumption, empty_weight, model_code, general_inspection, last_service, full_service_history, non-smoker_vehicle, emission_class, emissions_sticker, upholstery_colour, upholstery, production_date, previous_owner, other_fuel_types, power_consumption, energy_efficiency_class, co₂-efficiency, fuel_consumption_(wltp), co₂-emissions_(wltp), available_from, taxi_or_rental_car, availability, last_timing_belt_change, electric_range_(wltp), power_consumption_(wltp), battery_ownership, comfort_&_convenience, entertainment_&_media, safety_&_security, extras]
# Index: []

# %%
df.loc[df['model'] =='']
# Out:
#                                        short_description           make model  \
# 162                           Classe A 1.9 116ch A 180 d  Mercedes-Benz
# 184          Classe A 1.5 109ch A 180 CDI BlueEfficiency  Mercedes-Benz
# 186                           Classe A 1.5 116ch A 180 d  Mercedes-Benz
# 211                      Classe A 1.5 90ch A 160 CDI / d  Mercedes-Benz
# 213                           Classe A 1.5 116ch A 180 d  Mercedes-Benz
# ...                                                  ...            ...   ...
# 27638        1st Edition AWD Recharge Pure Electric Twin          Volvo
# 27681        1st Edition AWD Recharge Pure Electric Twin          Volvo
# 28020  Ultimate AWD Recharge Pure Electric Twin getön...          Volvo
# 28036        1st Edition AWD Recharge Pure Electric Twin          Volvo
# 28079        1st Edition AWD Recharge Pure Electric Twin          Volvo
#
#                                                 location       price  \
# ...

# %%
df
# Out:
#                                        short_description           make  \
# 0                                                    CDi  Mercedes-Benz
# 1                                                   350+  Mercedes-Benz
# 2                                       S 4Matic+ 8G-DCT  Mercedes-Benz
# 3                                         4Matic+ 7G-DCT  Mercedes-Benz
# 4                               200CDI BE Line 4M 7G-DCT  Mercedes-Benz
# ...                                                  ...            ...
# 29474                     T8 Twin Business Plus AWD Aut.          Volvo
# 29475        2.4i Momentum/ Airco/ NAP/ APK/ Elek. Ramen          Volvo
# 29476                    1.6 D DRIVe Start/Stop R-design          Volvo
# 29477  T5 AUT(8) MOMENTUM BUSINESS SCHUIFDAK 360GR CA...          Volvo
# 29478  2.9 Executive G. NETTE AUTO! LEER! NAVI! CRUIS...          Volvo
#
#           model                                           location  \
# ...

# %% [markdown]
# # body_type

# %%
df["body_type"] = [item[0] if type(item) == list else item for item in df["body_type"]]
df["body_type"] = df["body_type"].str.strip("\n").astype('str')
df["body_type"] = df["body_type"].str.strip(",").astype('str')
df["body_type"] = df["body_type"].str.replace(',', '')

# %%
df
# Out:
#                                        short_description           make  \
# 0                                                    CDi  Mercedes-Benz
# 1                                                   350+  Mercedes-Benz
# 2                                       S 4Matic+ 8G-DCT  Mercedes-Benz
# 3                                         4Matic+ 7G-DCT  Mercedes-Benz
# 4                               200CDI BE Line 4M 7G-DCT  Mercedes-Benz
# ...                                                  ...            ...
# 29474                     T8 Twin Business Plus AWD Aut.          Volvo
# 29475        2.4i Momentum/ Airco/ NAP/ APK/ Elek. Ramen          Volvo
# 29476                    1.6 D DRIVe Start/Stop R-design          Volvo
# 29477  T5 AUT(8) MOMENTUM BUSINESS SCHUIFDAK 360GR CA...          Volvo
# 29478  2.9 Executive G. NETTE AUTO! LEER! NAVI! CRUIS...          Volvo
#
#           model                                           location  \
# ...

# %% [markdown]
# # type

# %%
df["type"] = [item[0] if type(item) == list else item for item in df["type"]]
df["type"] = df["type"].str.strip("\n").astype('str')
df["type"] = df["type"].str.strip(",").astype('str')
df["type"] = df["type"].str.replace(',', '')

# %%
df
# Out:
#                                        short_description           make  \
# 0                                                    CDi  Mercedes-Benz
# 1                                                   350+  Mercedes-Benz
# 2                                       S 4Matic+ 8G-DCT  Mercedes-Benz
# 3                                         4Matic+ 7G-DCT  Mercedes-Benz
# 4                               200CDI BE Line 4M 7G-DCT  Mercedes-Benz
# ...                                                  ...            ...
# 29474                     T8 Twin Business Plus AWD Aut.          Volvo
# 29475        2.4i Momentum/ Airco/ NAP/ APK/ Elek. Ramen          Volvo
# 29476                    1.6 D DRIVe Start/Stop R-design          Volvo
# 29477  T5 AUT(8) MOMENTUM BUSINESS SCHUIFDAK 360GR CA...          Volvo
# 29478  2.9 Executive G. NETTE AUTO! LEER! NAVI! CRUIS...          Volvo
#
#           model                                           location  \
# ...

# %% [markdown]
# # doors

# %%
df["doors"] = [item[0] if type(item) == list else item for item in df["doors"]]
df["doors"] = df["doors"].str.strip("\n").astype('str')
df["doors"] = df["doors"].str.strip(",").astype('str')
df["doors"] = df["doors"].str.replace(',', '')

# %%
df
# Out:
#                                        short_description           make  \
# 0                                                    CDi  Mercedes-Benz
# 1                                                   350+  Mercedes-Benz
# 2                                       S 4Matic+ 8G-DCT  Mercedes-Benz
# 3                                         4Matic+ 7G-DCT  Mercedes-Benz
# 4                               200CDI BE Line 4M 7G-DCT  Mercedes-Benz
# ...                                                  ...            ...
# 29474                     T8 Twin Business Plus AWD Aut.          Volvo
# 29475        2.4i Momentum/ Airco/ NAP/ APK/ Elek. Ramen          Volvo
# 29476                    1.6 D DRIVe Start/Stop R-design          Volvo
# 29477  T5 AUT(8) MOMENTUM BUSINESS SCHUIFDAK 360GR CA...          Volvo
# 29478  2.9 Executive G. NETTE AUTO! LEER! NAVI! CRUIS...          Volvo
#
#           model                                           location  \
# ...

# %% [markdown]
# # country_version

# %%
df["country_version"] = [item[0] if type(item) == list else item for item in df["country_version"]]
df["country_version"] = df["country_version"].str.strip("\n").astype('str')
df["country_version"] = df["country_version"].str.strip(",").astype('str')
df["country_version"] = df["country_version"].str.replace(',', '')

# %%
df
# Out:
#                                        short_description           make  \
# 0                                                    CDi  Mercedes-Benz
# 1                                                   350+  Mercedes-Benz
# 2                                       S 4Matic+ 8G-DCT  Mercedes-Benz
# 3                                         4Matic+ 7G-DCT  Mercedes-Benz
# 4                               200CDI BE Line 4M 7G-DCT  Mercedes-Benz
# ...                                                  ...            ...
# 29474                     T8 Twin Business Plus AWD Aut.          Volvo
# 29475        2.4i Momentum/ Airco/ NAP/ APK/ Elek. Ramen          Volvo
# 29476                    1.6 D DRIVe Start/Stop R-design          Volvo
# 29477  T5 AUT(8) MOMENTUM BUSINESS SCHUIFDAK 360GR CA...          Volvo
# 29478  2.9 Executive G. NETTE AUTO! LEER! NAVI! CRUIS...          Volvo
#
#           model                                           location  \
# ...

# %% [markdown]
# # offer_number

# %%
df["offer_number"] = [item[0] if type(item) == list else item for item in df["offer_number"]]
df["offer_number"] = df["offer_number"].str.strip("\n").astype('str')
df["offer_number"] = df["offer_number"].str.strip(",").astype('str')
df["offer_number"] = df["offer_number"].str.replace(',', '')

# %%
df
# Out:
#                                        short_description           make  \
# 0                                                    CDi  Mercedes-Benz
# 1                                                   350+  Mercedes-Benz
# 2                                       S 4Matic+ 8G-DCT  Mercedes-Benz
# 3                                         4Matic+ 7G-DCT  Mercedes-Benz
# 4                               200CDI BE Line 4M 7G-DCT  Mercedes-Benz
# ...                                                  ...            ...
# 29474                     T8 Twin Business Plus AWD Aut.          Volvo
# 29475        2.4i Momentum/ Airco/ NAP/ APK/ Elek. Ramen          Volvo
# 29476                    1.6 D DRIVe Start/Stop R-design          Volvo
# 29477  T5 AUT(8) MOMENTUM BUSINESS SCHUIFDAK 360GR CA...          Volvo
# 29478  2.9 Executive G. NETTE AUTO! LEER! NAVI! CRUIS...          Volvo
#
#           model                                           location  \
# ...

# %% [markdown]
# # warranty

# %%
df["warranty"] = [item[0] if type(item) == list else item for item in df["warranty"]]
df["warranty"] = df["warranty"].str.strip("\n").astype('str')
df["warranty"] = df["warranty"].str.strip(",").astype('str')
df["warranty"] = df["warranty"].str.replace(',', '')

# %%
df.head(5)
# Out:
#           short_description           make     model  \
# 0                       CDi  Mercedes-Benz     A 160
# 1                      350+  Mercedes-Benz   EQE 350
# 2          S 4Matic+ 8G-DCT  Mercedes-Benz  A 45 AMG
# 3            4Matic+ 7G-DCT  Mercedes-Benz  A 35 AMG
# 4  200CDI BE Line 4M 7G-DCT  Mercedes-Benz  A 45 AMG
#
#                                             location       price  \
# 0  P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...  € 16,950.-
# 1       APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES  € 80,900.-
# 2  PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...  € 69,900.-
# 3  Carrer de Provença, 31 Local,  8029 BARCELONA, ES  € 46,990.-
# 4             CARRIL ARAGONES 4,  30007 CASILLAS, ES  € 16,800.-
#
#            body_type              type doors country_version offer_number  \
# 0  [\n, Compact, \n]             Used     5           Spain      7468157
# 1  [\n, Compact, \n]   Pre-registered     4           Spain      7054863
# ...

# %% [markdown]
# # gearbox

# %%
df["gearbox"] = [item[0] if type(item) == list else item for item in df["gearbox"]]
df["gearbox"] = df["gearbox"].str.strip("\n").astype('str')
df["gearbox"] = df["gearbox"].str.strip(",").astype('str')
df["gearbox"] = df["gearbox"].str.replace(',', '')

# %%
df.head(5)
# Out:
#           short_description           make     model  \
# 0                       CDi  Mercedes-Benz     A 160
# 1                      350+  Mercedes-Benz   EQE 350
# 2          S 4Matic+ 8G-DCT  Mercedes-Benz  A 45 AMG
# 3            4Matic+ 7G-DCT  Mercedes-Benz  A 35 AMG
# 4  200CDI BE Line 4M 7G-DCT  Mercedes-Benz  A 45 AMG
#
#                                             location       price  \
# 0  P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...  € 16,950.-
# 1       APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES  € 80,900.-
# 2  PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...  € 69,900.-
# 3  Carrer de Provença, 31 Local,  8029 BARCELONA, ES  € 46,990.-
# 4             CARRIL ARAGONES 4,  30007 CASILLAS, ES  € 16,800.-
#
#            body_type              type doors country_version offer_number  \
# 0  [\n, Compact, \n]             Used     5           Spain      7468157
# 1  [\n, Compact, \n]   Pre-registered     4           Spain      7054863
# ...

# %% [markdown]
# # desc

# %%
# bunu yapamadım.

# %%
df.head(5)
# Out:
#           short_description           make     model  \
# 0                       CDi  Mercedes-Benz     A 160
# 1                      350+  Mercedes-Benz   EQE 350
# 2          S 4Matic+ 8G-DCT  Mercedes-Benz  A 45 AMG
# 3            4Matic+ 7G-DCT  Mercedes-Benz  A 35 AMG
# 4  200CDI BE Line 4M 7G-DCT  Mercedes-Benz  A 45 AMG
#
#                                             location       price  body_type  \
# 0  P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...  € 16,950.-   Compact
# 1       APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES  € 80,900.-   Compact
# 2  PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...  € 69,900.-   Compact
# 3  Carrer de Provença, 31 Local,  8029 BARCELONA, ES  € 46,990.-   Compact
# 4             CARRIL ARAGONES 4,  30007 CASILLAS, ES  € 16,800.-   Compact
#
#                type doors country_version offer_number     warranty  \
# 0             Used     5           Spain      7468157    24 months
# ...

# %%
df1

# %%
df1=df0.copy()

# %%
[df1['Type']]

# %%
df1["Type"] = [item[0] if type(item) == list else item for item in df1["Type"]]
df1["Type"]

# %%
df1["Type"] = df1["Type"].str.strip("\n").astype('str')
df1["Type"] = df1["Type"].str.strip(",").astype('str')
df1['Type'] = df1['Type'].str.replace(',', '')

# %%
df1

# %%
for group1 in df ["make_model"].unique():
    for group2 in list (df["body_type"].unique()):
        cond2 = (df["make_model"]==group1) & (df["body_type"]==group2)
        df.loc[cond2, "Paint_Type"] = df.loc[cond2, "Paint_Type"].fillna (method="ffill").fillna(method="bfill")
for group1 in list (df["make_model"].unique()):
    cond1 = df["make_model"]==group1
    df.loc[cond1, "Paint_Type"] = df.loc[cond1, "Paint_Type"].fillna (method="ffill").fillna (method="bfill")
df["Paint_Type"] = df["Paint_Type"].fillna (method="ffill").fillna (method="bfill")

# %%
df.head(100)
